# %% [markdown]
# <center> <h1>Universidad Nacional de San Agustín de Arequipa</h1> </center>
# <center> <h1>Escuela Profesional de Ingeniería de Telecomunicaciones</h1> </center>
#
# <center> <h1> </h1> </center>
#
# <center><img src="https://user-images.githubusercontent.com/19308295/115939517-f1c6fe80-a463-11eb-989c-812ab4942586.png" width="380" height="4200"></center>

# %% [markdown]
# <center> <h2>Ingeniero Renzo Bolivar - Docente DAIE</h2> </center>

# %% [markdown]
# <center> <h1>Curso : Computación 2</h1> </center>

# %% [markdown]
# ![linea 1](https://user-images.githubusercontent.com/19308295/115926252-2b8a0c00-a448-11eb-9d9c-b43beaf0ff68.png)

# %% [markdown]
# <center> <h1>Excel a Python</h1> </center>

# %% [markdown]
# ![linea 1](https://user-images.githubusercontent.com/19308295/115926252-2b8a0c00-a448-11eb-9d9c-b43beaf0ff68.png)

# %%
import pandas as pd

rankgUNI = "WORLD UNIVERSITY RANKINGS.csv"

datos = pd.read_csv(rankgUNI)
datos.shape
# Out:
# (2000, 9)

# %%
datos.head()
# Out:
#    World Rank                            Institution        Location  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
#
#    National Rank Education Rank Employability Rank Faculty Rank Research Rank  \
# 0              1              1                  1            1             1
# 1              2              4                 12            2             7
# 2              3             11                  4            3             2
# 3              1              3                 25            4            10
# 4              2              7                 27            9             4
#
#    Score
# 0  100.0
# 1   96.7
# 2   95.1
# 3   94.1
# 4   93.3

# %%
datos.head(10)
# Out:
#    World Rank                            Institution        Location  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom
# 5           6                   Princeton University             USA
# 6           7                  University of Chicago             USA
# 7           8                    Columbia University             USA
# 8           9             University of Pennsylvania             USA
# 9          10     California Institute of Technology             USA
#
#    National Rank Education Rank Employability Rank Faculty Rank Research Rank  \
# 0              1              1                  1            1             1
# ...

# %%
datos.tail(7)
# Out:
#       World Rank                                        Institution Location  \
# 1993        1994                           Hanoi Medical University  Vietnam
# 1994        1995                        Kanazawa Medical University    Japan
# 1995        1996                           Bharathidasan University    India
# 1996        1997                     Federal University of Maranhão   Brazil
# 1997        1998        Jiangxi University of Finance and Economics    China
# 1998        1999                             University of Tarapacá    Chile
# 1999        2000  National Institute of Mental Health and Neuros...    India
#
#       National Rank Education Rank Employability Rank Faculty Rank  \
# 1993              6              -                  -            -
# 1994            118              -                  -            -
# 1995             66              -                  -            -
# 1996             56              -                  -            -
# ...

# %%
datos.isnull().sum()
# Out:
# World Rank            0
# Institution           0
# Location              0
# National Rank         0
# Education Rank        0
# Employability Rank    0
# Faculty Rank          0
# Research Rank         0
# Score                 0
# dtype: int64

# %%
import matplotlib.pyplot as plt

rankgUNI = "WORLD UNIVERSITY RANKINGS.csv"

datos = pd.read_csv(rankgUNI)
columna_y = "Faculty Rank"

plt.bar(range(len(datos)), datos[columna_y])
plt.title('Faculty Rank')
plt.show()

# %%
rankgUNI = "WORLD UNIVERSITY RANKINGS.csv"

datos = pd.read_csv(rankgUNI)
columna_y = "National Rank"

plt.bar(range(len(datos)), datos[columna_y])
plt.title('National Rank')
plt.show()

# %%
rankgUNI = "WORLD UNIVERSITY RANKINGS.csv"

datos = pd.read_csv(rankgUNI)
columna_y = "Education Rank"

plt.bar(range(len(datos)), datos[columna_y])
plt.title('Education Rank')
plt.show()

# %%
rankgUNI = "WORLD UNIVERSITY RANKINGS.csv"

datos = pd.read_csv(rankgUNI)
columna_y = "Employability Rank"

plt.bar(range(len(datos)), datos[columna_y])
plt.title('Employability Rank')
plt.show()

# %%
rankgUNI = "WORLD UNIVERSITY RANKINGS.csv"

datos = pd.read_csv(rankgUNI)
columna_y = "Research Rank"

plt.bar(range(len(datos)), datos[columna_y])
plt.title('Research Rank')
plt.show()

# %%
rankgUNI = "WORLD UNIVERSITY RANKINGS.csv"

datos = pd.read_csv(rankgUNI)
columna_y = "Score"

plt.bar(range(len(datos)), datos[columna_y])
plt.title('Score')
plt.show()

# %%
datos.describe()
# Out:
#         World Rank  National Rank        Score
# count  2000.000000    2000.000000  2000.000000
# mean   1000.500000      68.374000    71.586450
# std     577.494589      84.132189     5.079795
# min       1.000000       1.000000    65.700000
# 25%     500.750000      10.000000    67.700000
# 50%    1000.500000      33.000000    70.200000
# 75%    1500.250000      88.000000    74.100000
# max    2000.000000     335.000000   100.000000

# %%
rankgUNI = "WORLD UNIVERSITY RANKINGS.csv"

datos = pd.read_csv(rankgUNI)

nuevo_documento = datos[["World Rank", "Institution", "Location"]]

nuevo_documento.to_csv("nuevo_documento.csv", index=False)

# %%
R2 = "R02.csv"

datos2 = pd.read_csv(R2)
datos2.shape
# Out:
# (2000, 3)

# %%
datos2.head()
# Out:
#    World Rank                            Institution        Location
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5                   University of Oxford  United Kingdom

# %%
datos2.describe()
# Out:
#         World Rank
# count  2000.000000
# mean   1000.500000
# std     577.494589
# min       1.000000
# 25%     500.750000
# 50%    1000.500000
# 75%    1500.250000
# max    2000.000000

# %%
import pandas as pd

rankgUNI = "WORLD UNIVERSITY RANKINGS.csv"

datos = pd.read_csv(rankgUNI)

nuevo_documento = datos[datos["Location"] == "USA"]

nuevo_documento.to_csv("R02_USA.csv", index=False)

# %%
R2USA = "R02_USA.csv"

datos3 = pd.read_csv(R2USA)
datos3.shape
# Out:
# (335, 9)

# %%
datos3.head()
# Out:
#    World Rank                            Institution Location  National Rank  \
# 0           1                     Harvard University      USA              1
# 1           2  Massachusetts Institute of Technology      USA              2
# 2           3                    Stanford University      USA              3
# 3           6                   Princeton University      USA              4
# 4           7                  University of Chicago      USA              5
#
#   Education Rank Employability Rank Faculty Rank Research Rank  Score
# 0              1                  1            1             1  100.0
# 1              4                 12            2             7   96.7
# 2             11                  4            3             2   95.1
# 3              5                 15            6            79   92.6
# 4              8                 16           21            22   92.0

# %%
datos3.head(10)
# Out:
#    World Rank                            Institution Location  National Rank  \
# 0           1                     Harvard University      USA              1
# 1           2  Massachusetts Institute of Technology      USA              2
# 2           3                    Stanford University      USA              3
# 3           6                   Princeton University      USA              4
# 4           7                  University of Chicago      USA              5
# 5           8                    Columbia University      USA              6
# 6           9             University of Pennsylvania      USA              7
# 7          10     California Institute of Technology      USA              8
# 8          11                        Yale University      USA              9
# 9          12     University of California, Berkeley      USA             10
#
#   Education Rank Employability Rank Faculty Rank Research Rank  Score
# ...

# %%
datos3.tail(10)
# Out:
#      World Rank                                     Institution Location  \
# 325        1846                            Kettering University      USA
# 326        1861                     Franklin & Marshall College      USA
# 327        1876                                 Drew University      USA
# 328        1894           University of Arkansas at Little Rock      USA
# 329        1925                               Wellesley College      USA
# 330        1930  Florida Agricultural and Mechanical University      USA
# 331        1935                   Washington and Lee University      USA
# 332        1955                          University of Richmond      USA
# 333        1957                             Duquesne University      USA
# 334        1992                     University of North Florida      USA
#
#      National Rank Education Rank Employability Rank Faculty Rank  \
# 325            326              -                 77            -
# ...
